# %%
import urllib.request

client_id = "jvPesWUk2FGWsd_XyXXH"
client_secret = "5Wry8AytjH"

# %%
encText = urllib.parse.quote("sugu2000kr")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText
url
# Out:
# 'https://openapi.naver.com/v1/search/blog.json?query=sugu2000kr'

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

# %%
response = urllib.request.urlopen(request)
print(response.getcode())
# Out:
# 200

# %%
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Mon, 28 Mar 2022 07:38:27 +0900",
# "total": 2,
# "start": 1,
# "display": 2,
# "items": [
# {
# "title": "펭귄 식당",
# "link": "https:\/\/blog.naver.com\/twinshan4?Redirect=Log&logNo=130148471403",
# "description": "웃는바위(<b>sugu2000kr</b>)카페매니저A123.com - 4500+ Free Games A123.com - 4500+ Free Games 뜨는시간(로딩)이 조금 걸리네요.. 넘 재미난 게임이에요.. [출처] 팽귄식당 (한컴CQ교실/한컴미래로봇... ",
# "bloggername": "twinshan4님의블로그",
# "bloggerlink": "https://blog.naver.com/twinshan4",
# "postdate": "20121002"
#
# },
# {
# "title": "nrc선불제",
# "link": "https:\/\/blog.naver.com\/shdalma?Redirect=Log&logNo=60013885456",
# "description": "| 밥 일 꿈 2005/06/11 21:44 http://blog.naver.com/<b>sugu2000kr</b>/140013885299 출처블로그 : 행동은 생각을 지배한다 지금부터 내가 하고자 하는 이야기는, 통신으로 어떻게 돈을 벌 수 있는가에 대한 내용이야... 먼저는 통신이... ",
# "bloggername": "shdalma님의 블로그",
# "bloggerlink": "https://blog.naver.com/shdalma",
# "postdate": "20050613"
#
# }
# ]
# }
