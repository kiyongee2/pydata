# %%
import pandas as pd
dates = pd.date_range('20220326', periods=6)
dates
# Out:
# DatetimeIndex(['2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29',
#                '2022-03-30', '2022-03-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DateFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df = pd.DateFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:244, in __getattr__(name)
#     240     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     242     return _SparseArray
# --> 244 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'DateFrame'

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2022-03-26  1.448821 -0.374499 -0.508945  1.969108
# 2022-03-27  1.125607 -0.273494  0.119447 -1.286095
# 2022-03-28 -1.650598  1.128744  0.962990  1.230956
# 2022-03-29  1.462892 -0.214298 -0.411773 -0.790643
# 2022-03-30  1.357054 -0.967660  1.085718  1.027660
# 2022-03-31 -0.047882 -0.092352 -0.126208 -0.707820

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29',
#                '2022-03-30', '2022-03-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.values
# Out:
# array([[ 1.4488212 , -0.37449914, -0.50894455,  1.96910756],
#        [ 1.12560744, -0.27349384,  0.11944678, -1.2860952 ],
#        [-1.65059819,  1.12874415,  0.96298994,  1.23095573],
#        [ 1.46289163, -0.21429765, -0.41177287, -0.79064321],
#        [ 1.35705383, -0.96765984,  1.08571753,  1.02766027],
#        [-0.04788222, -0.09235227, -0.12620753, -0.70782002]])

# %%
df['A']
# Out:
# 2022-03-26    1.448821
# 2022-03-27    1.125607
# 2022-03-28   -1.650598
# 2022-03-29    1.462892
# 2022-03-30    1.357054
# 2022-03-31   -0.047882
# Freq: D, Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2022-03-26  1.448821 -0.374499 -0.508945  1.969108
# 2022-03-27  1.125607 -0.273494  0.119447 -1.286095
# 2022-03-28 -1.650598  1.128744  0.962990  1.230956

# %%
df.loc['2022-02-26', ['A']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:460, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1645833600000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# ...

# %%
df.loc['2022-03-26', ['A']]
# Out:
# A    1.448821
# Name: 2022-03-26 00:00:00, dtype: float64

# %%
df['A'] > 0
# Out:
# 2022-03-26     True
# 2022-03-27     True
# 2022-03-28    False
# 2022-03-29     True
# 2022-03-30     True
# 2022-03-31    False
# Freq: D, Name: A, dtype: bool
